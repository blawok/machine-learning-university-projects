# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
plt.figure(figsize=(10,5))
pic = Image.open(f'testData/v2-00000.png')
pix = np.array(pic)
plt.imshow(pix)

# %%
dfLabels = pd.read_csv('HASYv2/hasy-data-labels.csv')
dfLabels.head()
# Out:
#                      path  symbol_id latex  user_id
# 0  hasy-data/v2-00000.png         31     A       50
# 1  hasy-data/v2-00001.png         31     A       10
# 2  hasy-data/v2-00002.png         31     A       43
# 3  hasy-data/v2-00003.png         31     A       43
# 4  hasy-data/v2-00004.png         31     A     4435

# %%
dfSymbols = pd.read_csv('HASYv2/symbols.csv')
dfSymbols.head()
# Out:
#    symbol_id latex  training_samples  test_samples
# 0         31     A               137            22
# 1         32     B                53             8
# 2         33     C               120            14
# 3         34     D                50             8
# 4         35     E                48             6

# %%
dfSymbols.plot(x='symbol_id', y='training_samples', figsize=(20,5))
